# %%
import cv2
import numpy as np
import os
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
img_path = 'temp3/1990.jpg'
img = cv2.imread(img_path)

# %%
plt.figure()
plt.imshow(img)
plt.show()

# %%
import cv2
sal= cv2.saliency
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-1d38f9bb3cbd> in <module>
#       1 import cv2
# ----> 2 sal= cv2.saliency
#
# AttributeError: module 'cv2.cv2' has no attribute 'saliency'
