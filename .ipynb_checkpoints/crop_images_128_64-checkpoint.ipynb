# %%
import os
import numpy as np
import cv2

# %%
source_folder = 'bigger_dataset_115_64/pos'
dest_folder = 'bigger_dataset_115_64/pos_cropped'

# %%
crop_ratio_vert = 0.9 # between 0 and 1
crop_ratio_hor = 1.0

for image in os.listdir(source_folder):
    image_path = os.path.join(source_folder, image)
    img = cv2.imread(image_path)
    crop_width = int(crop_ratio_vert*img.shape[0])
    crop_height = int(crop_ratio_hor*img.shape[1])
    cropped_image = cv2.crop
    #shape = img.shape
    #cropped_image = image[]
    print(crop_width)
# Out:
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# ...
